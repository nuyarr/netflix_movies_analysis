# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
net = pd.read_csv('C:/Users/Mert/Downloads/movie_netflix.csv', encoding='latin-1')

# %%
net.head()
# Out:
#    index                 TITLE  RELEASE_YEAR  SCORE MAIN_GENRE MAIN_PRODUCTION
# 0      0       White Christmas          1954    7.5    romance              US
# 1      1  The Guns of Navarone          1961    7.5        war              US
# 2      2          My Fair Lady          1964    7.8      drama              US
# 3      3      Bonnie and Clyde          1967    7.7      drama              US
# 4      4           Dirty Harry          1971    7.7   thriller              US

# %%
net['TITLE'].value_counts()
# Out:
# White Christmas                                   1
# Girl, Interrupted                                 1
# Lagaan: Once Upon a Time in India                 1
# Road to Perdition                                 1
# Big Fish                                          1
# Swades                                            1
# Memoirs of a Geisha                               1
# Rang De Basanti                                   1
# Like Stars on Earth                               1
# Ip Man                                            1
# 3 Idiots                                          1
# Inception                                         1
# Warrior                                           1
# Django Unchained                                  1
# Rush                                              1
# Queen                                             1
# Drishyam                                          1
# Dangal                                            1
# ...

# %%
net.drop_duplicates()
# Out:
#     index                                           TITLE  RELEASE_YEAR  \
# 0       0                                 White Christmas          1954
# 1       1                            The Guns of Navarone          1961
# 2       2                                    My Fair Lady          1964
# 3       3                                Bonnie and Clyde          1967
# 4       4                                     Dirty Harry          1971
# 5       5                                    The Exorcist          1973
# 6       6                 Monty Python and the Holy Grail          1975
# 7       7                                     Taxi Driver          1976
# 8       8                                   Life of Brian          1979
# 9       9                                 The Blue Lagoon          1980
# 10     10                                           Annie          1982
# 11     11                                       Christine          1983
# ...

# %%
net.loc[net['SCORE'].idxmax()]
# Out:
# index                                                    46
# TITLE              David Attenborough: A Life on Our Planet
# RELEASE_YEAR                                           2020
# SCORE                                                   9.0
# MAIN_GENRE                                      documentary
# MAIN_PRODUCTION                                          GB
# Name: 46, dtype: object

# %%
net['MAIN_PRODUCTION'].value_counts()
# Out:
# US    29
# IN    10
# GB     6
# JP     1
# DE     1
# FR     1
# HK     1
# Name: MAIN_PRODUCTION, dtype: int64

# %%
net.plot(kind="scatter", x="MAIN_PRODUCTION", y="SCORE")
# Out:
# <AxesSubplot:xlabel='MAIN_PRODUCTION', ylabel='SCORE'>

# %%
sns.jointplot(x="SCORE", y="MAIN_PRODUCTION", data=net, size=4)
# Out:
# C:\Users\Mert\anaconda3\lib\site-packages\seaborn\axisgrid.py:2182: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(x="SCORE", y="MAIN_GENRE", data=net)
# Out:
# <AxesSubplot:xlabel='SCORE', ylabel='MAIN_GENRE'>

# %%
sns.violinplot(x="SCORE", y="MAIN_GENRE", data=net, size=6)
# Out:
# <AxesSubplot:xlabel='SCORE', ylabel='MAIN_GENRE'>

# %%
sns.pairplot(net.drop("SCORE", axis=1), hue="MAIN_GENRE", size=3)
# Out:
# C:\Users\Mert\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(net.drop("SCORE", axis=1), hue="MAIN_PRODUCTION", size=3, diag_kind="kde")
# Out:
# C:\Users\Mert\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1092\3723533747.py in <module>
# ----> 1 from pandas.tools.plotting import andrews_curves as ac
#       2 ac(net.drop("SCORE", axis=1), "MAIN_PRODUCTION")
#
# ModuleNotFoundError: No module named 'pandas.tools'

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.heatmap(net.corr(), center=0, cmap='Blues')
ax.set_title('Netflix Movie Heatmap')
# Out:
# Text(0.5, 1.0, 'Netflix Movie Heatmap')

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.heatmap(net.corr(), center=0, cmap='BrBG', annot=True)
# Out:
# <AxesSubplot:>
